# %% [markdown]
# # MATRICE DI CORRELAZIONE

# %% [markdown]
# Come prima operazione, importiamo le librerie necessarie

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels
import pandas as pd
import numpy as np

# %% [markdown]
# Successivamente si procede con l'importazione del dataset contenuto nella cartella "data". Per raggiungere tale scopo si utilizza il metodo **read_excel()** del modulo **pandas**

# %%
table = pd.read_excel('https://github.com/collab-uniba/PanelJamDataExtractor/blob/master/data/TabellaCompleta.xlsx?raw=true', index = False)

# %% [markdown]
# Una volta importato il dataset si devono eliminare alcune feature contenute in esso, questo perchè:
#
# -le feature **id_prog**,**id_panel**,**autore_panel** contengono delle stringhe che indicano rispettivamente, l'id dei progetti estratti, l'id dei panel contenuti in ogni progetto e il nome del creatore di ogni panel. Queste feature non sono rilevanti per il calcolo della matrice di correlazione(mostrata successivamente) e nemmeno per la costruzione del modello di regressione.
#
# -le feature **Likes**, **Views**, **Comments** e **time** fanno riferimento ai progetti e non ai singoli panel, per questo motivo non vengono considerati.
#
# Si procede con la costruzione della matrice di correlazione con lo scopo di osservare eventuali problemi di **multicollinearità** tra le feature. Se il grado di correlazione tra due feature è maggiore del limite consentito di **0.7**, se ne deve eliminare una delle due. La matrice verrà costruita utilizzando il metodo **corr()** del modulo **pandas**

# %%
#time = table['time'].tolist()
#table['time'] = list(map(lambda sub:int(''.join([ele for ele in sub if ele.isnumeric()])), time))
table = table.drop(columns = ['id_prog','id_panel','Likes','Views','Comments','autore_panel','time'])

corrMatrix = table.corr()
corrMatrix.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col2 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col3 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col4 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col5 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col7 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col8 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow0_col9 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col8 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col0 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col3 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col5 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col6 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col7 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col8 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow2_col9 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col0 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col2 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col4 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col5 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col6 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col7 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col8 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow3_col9 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col0 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col3 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col5 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col6 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col7 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow4_col9 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col2 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col4 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col6 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col7 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col8 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_bf953de6_a1c8_11ea_bc99_10e7c6da85farow5_col9 {
#             background-color:  #9ebeff;
#             color:  #000000;

# %% [markdown]
# Come si può osservare dalla matrice, tra la feature **tot_views_autore** e **stars_autore** c'è un elevato grado di correlazione (**0.85**), questo è dovuto dalla presenza di entrambe le feature nel calcolo del ranking di un autore. Dato che star_count rappresenta la misura di apprezzamento migliore, si decide di eliminare tot_views_autore. A supporto di questa decisione è la presenza di un alto grado di correlazione tra tot_views_autore e **tot_loves_autore** (**0.76**).
#
# Nonostante il grado di correlazione tra tot_loves_autore e stars_autore sia di **0.74**, esso è comunque nel limite tollerabile.
# Inoltre, questo valore è dovuto dalla presenza di tot_loves_autore nel calcolo del ranking. Di seguito viene mostrata la matrice di correlazione corretta.

# %%
table = table.drop(columns = ['tot_views_autore'])
corrMatrix = table.corr()
corrMatrix.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col2 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col3 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col4 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col5 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow0_col8 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col7 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col0 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col3 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col5 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col6 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col7 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow2_col8 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col0 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col2 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col4 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col5 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col6 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col7 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow3_col8 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col0 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col3 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col5 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col6 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow4_col8 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col2 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col4 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col6 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col7 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow5_col8 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow6_col0 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow6_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow6_col2 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow6_col3 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow6_col4 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_c1badb5a_a1c8_11ea_a164_10e7c6da85farow6_col5 {
#             background-color:  #f7a688;
#             color:  #000000;

# %% [markdown]
# # MODELLO DI REGRESSIONE

# %% [markdown]
# Dopo aver costruito la matrice di correlazione ed eliminato eventuali problemi di collinearità, si procede con la costruzione del modello di regressione. Il primo passaggio consiste nel dividere il dataset in due, dove il primo conterrà solo le feature non numeriche ed è stato etichettato con il nome **logit**, il secondo conterrà solo le feature numeriche ed è stato etichettato con il nome **numerical**. In seguito si spiegherà il motivo di questa divisione.

# %%
featureTable = table
logit = featureTable.drop(columns = ['project_depth','stars_autore','followers_autore','tot_loves_autore',
                'ranking_autore','panel_stars'])
numerical = featureTable.drop(columns = ['remixed','has_avatar_autore','has_bio_autore'])

# %% [markdown]
# La feature **project_depth** all'interno della tabella, sta ad indicare la profondità di ogni progetto, ovvero il numero di vignette contenute in esso. Se, per una vignetta, è presente quella successiva allora il valore di **extended** relativa ad essa sarà True, altrimenti False. In questa maniera, se un progetto dovesse avere solo una vignetta(ovvero quella del creatore del progetto stesso), la project_depth relativa avrà valore 1. Al fine di ottenere una corretta costruzione del modello di regressione, il valore della project_depth di un progetto non esteso, dovrà necessariamente essere pari a 0, per questo motivo si è deciso di sottrare 1 alle profondità di tutti i progetti.

# %%
numerical['project_depth'] = numerical['project_depth'] - 1

# %% [markdown]
# bisogna effettuare una log-normalizzazione delle feature numeriche in quanto alcune di esse contengono valori troppo grandi. Dopo di chè si procede alla ricostruzione della tabella, andando ad unire la tabella numerica(ottenuta dalla log-normalizzazione) alla tabella non numerica.

# %%
normTable = np.log1p(numerical)
normTable['remixed'] = logit['remixed']
normTable['has_avatar_autore'] = logit['has_avatar_autore']
normTable['has_bio_autore'] = logit['has_bio_autore']

# %% [markdown]
# Per costruire il modello di regressione si è utilizzata la funzione **glm** del package **statsmodel**, alla quale sono stati passati in input 3 parametri.
#
# -**formula**: prima del simbolo tilde (~) si deve specificare la variabile dipendente, mentre dopo bisogna specificare le variabili indipendenti, i quali costituiranno i predittori del modello.
#
# -**data**: la tabella da cui estrarre i valori delle variabili indipendenti.
#
# -**family**: specifica il modello di regressione che si vuole andare a costruire, in questo caso binomial ed è specificato da **sm.families.Binomial()**.

# %%
formula = """remixed ~ stars_autore + project_depth + followers_autore + tot_loves_autore +
             has_bio_autore + has_avatar_autore + ranking_autore + panel_stars"""

model = smf.glm(formula = formula, data = normTable, family=sm.families.Binomial(statsmodels.genmod.families.links.logit)).fit()
print(model.summary())
# Out:
#                           Generalized Linear Model Regression Results
# ===============================================================================================
# Dep. Variable:     ['remixed[False]', 'remixed[True]']   No. Observations:                13748
# Model:                                             GLM   Df Residuals:                    13739
# Model Family:                                 Binomial   Df Model:                            8
# Link Function:                                   logit   Scale:                          1.0000
# Method:                                           IRLS   Log-Likelihood:                -5249.2
# Date:                                 Fri, 29 May 2020   Deviance:                       10498.
# Time:                                         18:24:11   Pearson chi2:                 1.31e+04
# No. Iterations:                                      6
# Covariance Type:                             nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -4.4456      0.221    -20.096      0.000      -4.879      -4.012
# has_bio_autore[T.True]        0.0763      0.059      1.300      0.194      -0.039       0.191
# has_avatar_autore[T.True]    -0.1233      0.147     -0.840      0.401      -0.411       0.165
# stars_autore                 -0.0451      0.024     -1.879      0.060      -0.092       0.002
# project_depth                 3.0279      0.067     45.416      0.000       2.897       3.159
# followers_autore             -0.0061      0.034     -0.180      0.857      -0.072       0.060
# tot_loves_autore              0.0609      0.029      2.106      0.035       0.004       0.118
# ranking_autore               -0.1211      0.031     -3.906      0.000      -0.182      -0.060
# panel_stars                   0.6320      0.037     16.922      0.000       0.559       0.705
# =============================================================================================
# d:\dev-cpp\anaconda\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Calling Family(..) with a link class as argument is deprecated.
# Use an instance of a link class instead.
#   after removing the cwd from sys.path.
