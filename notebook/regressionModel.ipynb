# %% [markdown]
# # MATRICE DI CORRELAZIONE

# %% [markdown]
# Come prima operazione, importiamo le librerie necessarie

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels
import pandas as pd
import numpy as np

# %% [markdown]
# Successivamente si procede con l'importazione del dataset contenuto nella cartella "data". Per raggiungere tale scopo si utilizza il metodo **read_excel()** del modulo **pandas**

# %%
table = pd.read_excel('https://github.com/collab-uniba/PanelJamDataExtractor/blob/master/data/TabellaCompleta.xlsx?raw=true', index = False)

# %% [markdown]
# Una volta importato il dataset si devono eliminare alcune feature contenute in esso, questo perchè:
#
# -le feature **id_prog**,**id_panel**,**panel_author** contengono delle stringhe che indicano rispettivamente, l'id dei progetti estratti, l'id dei panel contenuti in ogni progetto e il nome del creatore di ogni panel. Queste feature non sono rilevanti per il calcolo della matrice di correlazione(mostrata successivamente) e nemmeno per la costruzione del modello di regressione.
#
# -le feature **Likes**, **Views**, **Comments** e **time** fanno riferimento ai progetti e non ai singoli panel, per questo motivo non vengono considerati.
#
# Si procede con la costruzione della matrice di correlazione con lo scopo di osservare eventuali problemi di **multicollinearità** tra le feature. Se il grado di correlazione tra due feature è maggiore del limite consentito di **0.7**, se ne deve eliminare una delle due. La matrice verrà costruita utilizzando il metodo **corr()** del modulo **pandas**

# %%
#time = table['time'].tolist()
#table['time'] = list(map(lambda sub:int(''.join([ele for ele in sub if ele.isnumeric()])), time))
table = table.drop(columns = ['id_prog','id_panel','Likes','Views','Comments','panel_author','time','author_stars'])

corrMatrix = table.corr()
corrMatrix.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col2 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col3 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col5 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col6 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col7 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow0_col8 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col0 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col3 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col4 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col5 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col6 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col7 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow2_col8 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col0 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col2 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col5 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col6 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col7 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow3_col8 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col3 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col5 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col6 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col7 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow4_col8 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col0 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col2 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col4 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col6 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col7 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow5_col8 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow6_col0 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow6_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow6_col2 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow6_col3 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow6_col4 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_b80ed61a_a673_11ea_a043_10e7c6da85farow6_col5 {
#             background-color:  #f29274;
#             color:  #000000;

# %% [markdown]
# Come si può osservare dalla matrice, c'è un alto grado di correlazione tra **tot_loves_author** e **author_stars** (**0.76**) superiore al limite di **0.7**. Questo è dovuto dalla presenza di entrambe le feature nel calcolo del ranking d'autore, per questo si decide di eliminare tot_views_author.

# %%
table = table.drop(columns = ['tot_views_author'])
corrMatrix = table.corr()
corrMatrix.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow0_col2 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow0_col3 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow0_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow0_col5 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow0_col6 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow0_col7 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow2_col0 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow2_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow2_col3 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow2_col4 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow2_col5 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow2_col6 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow2_col7 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow3_col0 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow3_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow3_col2 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow3_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow3_col5 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow3_col6 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow3_col7 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow4_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow4_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow4_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow4_col3 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow4_col5 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow4_col6 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow4_col7 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow5_col0 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow5_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow5_col2 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow5_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow5_col4 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow5_col6 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow5_col7 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow6_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow6_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow6_col2 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow6_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow6_col4 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow6_col5 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow6_col7 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow7_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow7_col1 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow7_col2 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f6ad40ba_a673_11ea_89b3_10e7c6da85farow7_col3 {
#             background-color:  #5673e0;
#             color:  #000000;

# %% [markdown]
# # MODELLO DI REGRESSIONE

# %% [markdown]
# Dopo aver costruito la matrice di correlazione ed eliminato eventuali problemi di collinearità, si procede con la costruzione del modello di regressione. Il primo passaggio consiste nel dividere il dataset in due, dove il primo conterrà solo le feature non numeriche ed è stato etichettato con il nome **logit**, il secondo conterrà solo le feature numeriche ed è stato etichettato con il nome **numerical**. In seguito si spiegherà il motivo di questa divisione.

# %%
featureTable = table
logit = featureTable.drop(columns = ['project_depth','author_followers','tot_loves_author',
                'author_ranking','panel_stars'])
numerical = featureTable.drop(columns = ['extended','has_avatar_author','has_bio_author'])

# %% [markdown]
# bisogna effettuare una log-normalizzazione delle feature numeriche in quanto alcune di esse contengono valori troppo grandi. Dopo di chè si procede alla ricostruzione della tabella, andando ad unire la tabella numerica(ottenuta dalla log-normalizzazione) alla tabella non numerica.

# %%
normTable = np.log1p(numerical)
normTable['extended'] = logit['extended']
normTable['has_avatar_author'] = logit['has_avatar_author']
normTable['has_bio_author'] = logit['has_bio_author']

# %% [markdown]
# Per costruire il modello di regressione si è utilizzata la funzione **glm** del package **statsmodel**, alla quale sono stati passati in input 3 parametri.
#
# -**formula**: prima del simbolo tilde (~) si deve specificare la variabile dipendente, mentre dopo bisogna specificare le variabili indipendenti, i quali costituiranno i predittori del modello.
#
# -**data**: la tabella da cui estrarre i valori delle variabili indipendenti.
#
# -**family**: specifica il modello di regressione che si vuole andare a costruire, in questo caso binomial ed è specificato da **sm.families.Binomial()**.

# %%
formula = """extended ~ project_depth + author_followers + tot_loves_author +
             has_bio_author + has_avatar_author + author_ranking + panel_stars"""

model = smf.glm(formula = formula, data = normTable, family=sm.families.Binomial(statsmodels.genmod.families.links.logit)).fit()
print(model.summary())
# Out:
#                            Generalized Linear Model Regression Results
# =================================================================================================
# Dep. Variable:     ['extended[False]', 'extended[True]']   No. Observations:                13748
# Model:                                               GLM   Df Residuals:                    13740
# Model Family:                                   Binomial   Df Model:                            7
# Link Function:                                     logit   Scale:                          1.0000
# Method:                                             IRLS   Log-Likelihood:                -5333.8
# Date:                                   Thu, 04 Jun 2020   Deviance:                       10668.
# Time:                                           16:59:24   Pearson chi2:                 1.60e+04
# No. Iterations:                                        6
# Covariance Type:                               nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -6.6121      0.219    -30.152      0.000      -7.042      -6.182
# has_bio_author[T.True]        0.0832      0.058      1.437      0.151      -0.030       0.197
# has_avatar_author[T.True]    -0.1122      0.145     -0.773      0.440      -0.397       0.172
# project_depth                 3.8945      0.084     46.541      0.000       3.730       4.059
# author_followers             -0.0347      0.029     -1.180      0.238      -0.092       0.023
# tot_loves_author              0.0232      0.023      1.018      0.309      -0.021       0.068
# author_ranking               -0.1054      0.026     -4.109      0.000      -0.156      -0.055
# panel_stars                   0.6097      0.036     16.889      0.000       0.539       0.680
# =============================================================================================
# d:\dev-cpp\anaconda\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Calling Family(..) with a link class as argument is deprecated.
# Use an instance of a link class instead.
#   after removing the cwd from sys.path.

# %%
print(np.exp(model.params))
# Out:
# Intercept                     0.001344
# has_bio_author[T.True]        1.086741
# has_avatar_author[T.True]     0.893892
# project_depth                49.131351
# author_followers              0.965896
# tot_loves_author              1.023486
# author_ranking                0.899986
# panel_stars                   1.839916
# dtype: float64
